# %%
import geopandas as gpd
import pandas as pd
import geoplot as gplt
import geoplot.crs as gcrs
contiguous_usa = gpd.read_file(gplt.datasets.get_path('contiguous_usa'))
gplt.choropleth(contiguous_usa, hue='population')
# Out:
# <AxesSubplot:>

# %%
usa_map_data = pd.read_csv("contiguous_usa.csv")
print(usa_map_data)
# Out:
#    state adm1_code  population  \
# 0     MN  USA-3514     5303925
# 1     MT  USA-3515      989415
# 2     ND  USA-3516      672591
# 3     ID  USA-3518     1567582
# 4     WA  USA-3519     6724540
# 5     AZ  USA-3520     6392017
# 6     CA  USA-3521    37253956
# 7     CO  USA-3522     5029196
# 8     NV  USA-3523     2700551
# 9     NM  USA-3524     2059179
# 10    OR  USA-3525     3831074
# 11    UT  USA-3526     2763885
# 12    WY  USA-3527      563626
# 13    AR  USA-3528     2915918
# 14    IA  USA-3529     3046355
# 15    KS  USA-3530     2853118
# 16    MO  USA-3531     5988927
# 17    NE  USA-3532     1826341
# 18    OK  USA-3533     3751351
# 19    SD  USA-3534      814180
# 20    LA  USA-3535     4533372
# 21    TX  USA-3536    25145561
# 22    CT  USA-3537     3574097
# 23    MA  USA-3513     6547629
# 24    NH  USA-3538     1316470
# 25    RI  USA-3539     1052567
# 26    VT  USA-3540      625741
# 27    AL  USA-3541     4779736
# 28    FL  USA-3542    18801310
# 29    GA  USA-3543     9687653
# 30    MS  USA-3544     2967297
# 31    SC  USA-3545     4625364
# 32    IL  USA-3546    12830632
# 33    IN  USA-3547     6483802
# 34    KY  USA-3548     4339367
# 35    NC  USA-3549     9535483
# 36    OH  USA-3550    11536504
# 37    TN  USA-3551     6346105
# 38    VA  USA-3552     8001024
# 39    WI  USA-3553     5686986
# 40    WV  USA-3554     1852994
# 41    DE  USA-3555      897934
# 42    MD  USA-3557     5773552
# 43    NJ  USA-3558     8791894
# 44    NY  USA-3559    19378102
# 45    PA  USA-3560    12702379
# 46    ME  USA-3561     1328361
# 47    MI  USA-3562     9883640
#
#                                              geometry
# 0   POLYGON ((-89.59940899999999 48.010274, -89.48...
# 1   POLYGON ((-111.194189 44.561156, -111.291548 4...
# 2   POLYGON ((-96.601359 46.351357, -96.5389080000...
# 3   POLYGON ((-111.049728 44.488163, -111.050245 4...
# 4   POLYGON ((-116.998073 46.33017, -116.906528 46...
# 5   POLYGON ((-109.045225 36.999912, -109.043673 3...
# 6   POLYGON ((-114.354901 34.464667, -114.165972 3...
# 7   POLYGON ((-102.050174 40.000815, -102.040123 3...
# 8   POLYGON ((-114.030528 36.994099, -114.023629 3...
# 9   POLYGON ((-103.001614 33.879948, -103.001614 3...
# 10  POLYGON ((-117.028252 42.000021, -117.028252 4...
# 11  POLYGON ((-109.053183 41.001994, -109.045225 3...
# 12  POLYGON ((-111.067194 44.541597, -111.071406 4...
# 13  POLYGON ((-89.662919 36.023073, -89.673513 35....
# 14  POLYGON ((-90.15663600000001 42.103735, -90.21...
# 15  POLYGON ((-94.604814 39.139859, -94.615382 38....
# 16  POLYGON ((-94.617501 36.999912, -94.622798 36....
# 17  POLYGON ((-95.45254 40.215143, -95.322884 40.0...
# 18  POLYGON ((-94.62861100000001 36.540586, -94.43...
# 19  POLYGON ((-96.75427000000001 42.633961, -97.02...
# 20  POLYGON ((-89.21767 29.29108, -89.408387 29.15...
# 21  POLYGON ((-93.578236 31.216131, -93.4898440000...
# 22  POLYGON ((-72.876166 41.220559, -73.647887 40....
# 23  POLYGON ((-69.884799 41.922764, -69.9652070000...
# 24  POLYGON ((-71.503511 45.007796, -71.505087 45....
# 25  POLYGON ((-71.14790000000001 41.647587, -71.12...
# 26  POLYGON ((-71.503511 45.007796, -71.6204550000...
# 27  POLYGON ((-85.05441500000001 31.108696, -85.00...
# 28  POLYGON ((-80.056539 26.88, -80.088015 26.2057...
# 29  POLYGON ((-80.86500700000001 32.033161, -81.33...
# 30  POLYGON ((-88.16696399999999 34.999673, -88.09...
# 31  POLYGON ((-78.554114 33.861422, -79.06067 33.4...
# 32  POLYGON ((-90.640818 42.505364, -89.620054 42....
# 33  POLYGON ((-84.80675599999999 41.677741, -84.80...
# 34  POLYGON ((-81.97253600000001 37.535952, -82.37...
# 35  POLYGON ((-75.868077 36.55118, -75.72731 35.55...
# 36  POLYGON ((-82.210661 38.57948, -82.340834 38.4...
# 37  POLYGON ((-81.679376 36.585571, -81.704775 36....
# 38  POLYGON ((-78.345625 39.405504, -77.8349840000...
# 39  POLYGON ((-86.48156299999999 45.323177, -86.26...
# 40  POLYGON ((-77.722796 39.322432, -77.834985 39....
# 41  POLYGON ((-75.319867 38.959948, -75.0718349999...
# 42  POLYGON ((-75.048385 38.448765, -75.05673 38.4...
# 43  POLYGON ((-73.912796 40.960187, -73.952325 40....
# 44  POLYGON ((-74.679028 41.355486, -74.840439 41....
# 45  POLYGON ((-74.89175400000001 40.081791, -75.12...
# 46  POLYGON ((-67.137344 45.137452, -66.9646599999...
# 47  POLYGON ((-90.395278 46.611677, -90.3555900000...
